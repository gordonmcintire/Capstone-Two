# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

df
# Out:
#         Season              DateTime          HomeTeam        AwayTeam  FTHG  \
# 0      1993-94  1993-08-14T00:00:00Z           Arsenal        Coventry     0
# 1      1993-94  1993-08-14T00:00:00Z       Aston Villa             QPR     4
# 2      1993-94  1993-08-14T00:00:00Z           Chelsea       Blackburn     1
# 3      1993-94  1993-08-14T00:00:00Z         Liverpool  Sheffield Weds     2
# 4      1993-94  1993-08-14T00:00:00Z          Man City           Leeds     1
# ...        ...                   ...               ...             ...   ...
# 10729  2020-21  2021-04-11T14:05:00Z          West Ham       Leicester     3
# 10730  2020-21  2021-04-11T16:30:00Z         Tottenham      Man United     1
# 10731  2020-21  2021-04-11T19:00:00Z  Sheffield United         Arsenal     0
# 10732  2020-21  2021-04-12T18:00:00Z         West Brom     Southampton     3
# 10733  2020-21  2021-04-12T20:15:00Z          Brighton         Everton     0
#
# ...

# %%
df = pd.read_csv('eplresults.csv')
df['FTR'].value_counts()
df=df.replace('H', 'Home Win')
df=df.replace('A', 'Away Win')
df=df.replace('D', 'Draw')
df2=df[['Season', 'DateTime', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR']]

# %%
covidseason = df.loc[10044:10423]
covidseason['FTR'].value_counts()
covidseason
# Out:
#         Season              DateTime        HomeTeam          AwayTeam  FTHG  \
# 10044  2019-20  2019-08-09T20:00:00Z       Liverpool           Norwich     4
# 10045  2019-20  2019-08-10T12:30:00Z        West Ham          Man City     0
# 10046  2019-20  2019-08-10T15:00:00Z     Bournemouth  Sheffield United     1
# 10047  2019-20  2019-08-10T15:00:00Z         Burnley       Southampton     3
# 10048  2019-20  2019-08-10T15:00:00Z  Crystal Palace           Everton     0
# ...        ...                   ...             ...               ...   ...
# 10419  2019-20  2020-07-26T16:00:00Z       Leicester        Man United     0
# 10420  2019-20  2020-07-26T16:00:00Z        Man City           Norwich     5
# 10421  2019-20  2020-07-26T16:00:00Z       Newcastle         Liverpool     1
# 10422  2019-20  2020-07-26T16:00:00Z     Southampton  Sheffield United     3
# 10423  2019-20  2020-07-26T16:00:00Z        West Ham       Aston Villa     1
#
# ...

# %%
sns.countplot(data=covidseason,
              x='FTR')
plt.xlabel('')
plt.ylabel('Count')
plt.title('2020/2021 Match Results')
sns.despine()
plt.show()

# %%
sns.countplot(data=df2,
              x='FTR', order=['Home Win', 'Away Win', 'Draw'])
plt.xlabel('')
plt.ylabel('Count')
plt.title('2020/2021 Match Results')
sns.despine()
plt.show()

# %%
df['HomeTeam'].value_counts()
# Out:
# Liverpool           533
# Chelsea             532
# Tottenham           532
# Arsenal             532
# Man United          532
# Everton             532
# Newcastle           494
# West Ham            476
# Aston Villa         474
# Man City            439
# Southampton         399
# Blackburn           327
# Sunderland          304
# Leicester           283
# Fulham              283
# Middlesbrough       266
# Bolton              247
# West Brom           244
# Leeds               228
# Crystal Palace      208
# Stoke               190
# Norwich             156
# Coventry            156
# Charlton            152
# Wigan               152
# Wimbledon           137
# Sheffield Weds      137
# Watford             133
# Birmingham          133
# Derby               133
# Swansea             133
# Portsmouth          133
# Burnley             130
# Wolves              129
# QPR                 118
# Hull                 95
# Bournemouth          95
# Ipswich              80
# ...

# %%
df[df['Season'] == '2019-20']
# Out:
#         Season              DateTime        HomeTeam          AwayTeam  FTHG  \
# 10044  2019-20  2019-08-09T20:00:00Z       Liverpool           Norwich     4
# 10045  2019-20  2019-08-10T12:30:00Z        West Ham          Man City     0
# 10046  2019-20  2019-08-10T15:00:00Z     Bournemouth  Sheffield United     1
# 10047  2019-20  2019-08-10T15:00:00Z         Burnley       Southampton     3
# 10048  2019-20  2019-08-10T15:00:00Z  Crystal Palace           Everton     0
# ...        ...                   ...             ...               ...   ...
# 10419  2019-20  2020-07-26T16:00:00Z       Leicester        Man United     0
# 10420  2019-20  2020-07-26T16:00:00Z        Man City           Norwich     5
# 10421  2019-20  2020-07-26T16:00:00Z       Newcastle         Liverpool     1
# 10422  2019-20  2020-07-26T16:00:00Z     Southampton  Sheffield United     3
# 10423  2019-20  2020-07-26T16:00:00Z        West Ham       Aston Villa     1
#
# ...

# %%
df.loc[10332]
# Out:
# Season                   2019-20
# DateTime    2020-06-17T18:00:00Z
# HomeTeam             Aston Villa
# AwayTeam        Sheffield United
# FTHG                           0
# FTAG                           0
# FTR                         Draw
# HTHG                           0
# HTAG                           0
# HTR                         Draw
# Referee                 M Oliver
# HS                            14
# AS                             5
# HST                            6
# AST                            1
# HC                            12
# AC                             4
# HF                            11
# AF                            14
# HY                             1
# AY                             1
# HR                             0
# AR                             0
# Name: 10332, dtype: object

# %%
cvseason = df.loc[10332:10423]

# %%
precvseason = df.loc[10044:10331]

# %%
precvseason[precvseason['FTR'] == 'Home Win']
print('Home Winning Percentage:', 129/380)
# Out:
# Home Winning Percentage: 0.3394736842105263

# %%
precvseason[precvseason['FTR'] == 'Away Win']
print('Away Winning Percentage:', 87/380)
# Out:
# Away Winning Percentage: 0.22894736842105262

# %%
precvseason[precvseason['FTR'] == 'Draw']
print('Drawing Percentage:', 72/380)
# Out:
# Drawing Percentage: 0.18947368421052632

# %%
sns.countplot(data=precvseason,
              x='FTR')
plt.xlabel('')
plt.ylabel('Count')
plt.title('Pre-Covid Match Results')
sns.despine()
plt.show()

# %%
sns.countplot(data=cvseason,
              x='FTR', order=['Home Win', 'Away Win', 'Draw'])
plt.xlabel('')
plt.ylabel('Count')
plt.title('Post-Covid Match Results')
sns.despine()
plt.show()

# %%
sns.countplot(data=df,
              x='FTR', order=['Home Win', 'Away Win', 'Draw'])
plt.xlabel('')
plt.ylabel('Count')
plt.title('Historical Match Results')
sns.despine()
plt.show()

# %%
df[df['FTR'] == 'Home Win']
print('Home Winning Percentage', 4929/10733)
# Out:
# Home Winning Percentage 0.45923786452995435

# %%
print('This is a start to the EDA for this Capstone Two. I dont think I have to clean it much more. My goal is to find the affect that covid19 lockdown has on match results and events. It can be said initially that no fans results in fewer draws')
# Out:
# This is a start to the EDA for this Capstone Two. I dont think I have to clean it much more. My goal is to find the affect that covid19 lockdown has on match results and events. It can be said initially that no fans results in fewer draws
